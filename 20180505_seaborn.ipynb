# %%
import seaborn as sns
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(tips['total_bill'],kde=False,bins=30)
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg')
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.pairplot(tips,hue='sex')

# %%
sns.rugplot(tips['total_bill'])
#dashmark for every single point

# %%
sns.barplot(x='sex',y='total_bill',data=tips)

# %%
sns.barplot(x='candidate_rejection_reason',y='min_salary_range',data=df)

# %%
sns.countplot(x='candidate_rejection_reason',data=df)

# %%
sns.violinplot(x='candidate_rejection_reason',y='min_salary_range',data=df,hue='info_asked',split=True)

# %%
df = pd.read_csv('teste_valores_rvl.csv')

# %%
voos = sns.load_dataset('flights')
voos.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
hm = df.corr()
sns.heatmap(hm, annot = True,cmap='coolwarm')

# %%
fp = voos.pivot_table(index='month',columns='year',values='passengers')

# %%
sns.heatmap(fp,cmap='coolwarm',linewidths=0.5)

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.pairplot(iris)

# %%
sns.PairGrid(iris)

# %%
sns.lmplot(x='total_bill', y= 'tip', data = tips)
